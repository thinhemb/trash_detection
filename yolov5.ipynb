# %%
import torch
from IPython.display import Image, clear_output  # to display images

clear_output()
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 1.9.0+cpu (CPU)

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
# %cd /content/gdrive/MyDrive/yolov5
# %pip install -qr requirements.txt

# %%
# !pip3 install clearml

# %%
# %%bash
# export api=`cat <<EOP
# api {
#     # Đỗ Viết Thịnh's workspace
#     web_server: https://app.community.clear.ml
#     api_server: https://api.community.clear.ml
#     files_server: https://files.community.clear.ml
#     credentials {
#         "access_key" = "PHPEJ0VJSQV981BGU97F"
#         "secret_key" = "DGLUdilY4ov7ACHqZ5jHvFiuT9Zws8tD8hyOlFcTShiQLCebix"
#     }
# }
# EOP
# echo "$api" > /root/clearml.conf

# %%
import clearml
from clearml import Task
task = Task.init(project_name='My_Work', task_name='MyTask1')
logger = task.get_logger

# %%
python train.py --img 640 --batch 8 --epochs 5 --data data.yaml --weights runs/train/exp/weights/last.pt
# Out:
#   File "<ipython-input-3-e28367c65df3>", line 1
#     python train.py --img 640 --batch 8 --epochs 5 --data data.yaml --weights runs/train/exp/weights/last.pt
#            ^
# SyntaxError: invalid syntax

# %%
# %load_ext tensorboard
# %tensorboard --logdir runs/train

# %%
def plot_results(file='/content/gdrive/MyDrive/results.csv'):
    fig, ax = plt.subplots(2, 5, figsize=(12, 6), tight_layout=True)
    ax = ax.ravel()
    data = pd.read_csv(file)
    s = [x.strip() for x in data.columns]
    x = data.values[:, 0]
    for i, j in enumerate([1, 2, 3, 4, 5, 8, 9, 10, 6, 7]):
      y = data.values[:, j]
      ax[i].plot(x, y, marker='.', label="results", linewidth=2, markersize=8)
      ax[i].set_title(s[j], fontsize=12)
                
    ax[1].legend()
    fig.savefig('/content/gdrive/MyDrive/results.png', dpi=200)
plot_results()

# %%
# !cd yolov5/
# !python val.py --weight results/weights/last.pt --img 640 --conf 0.2 --iou 0.45 --data data.yaml
# Out:
# /bin/bash: line 0: cd: yolov5/: No such file or directory
# val: data=data.yaml, weights=['results/weights/last.pt'], batch_size=32, imgsz=640, conf_thres=0.2, iou_thres=0.45, task=val, device=, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False
# YOLOv5 🚀 v5.0-383-g8b18b66 torch 1.9.0+cpu CPU
#
# Fusing layers...
# Model Summary: 308 layers, 21057843 parameters, 0 gradients, 50.4 GFLOPs
# val: Scanning '../yolov5/data_yolov5/val/labels' images and labels...491 found,
# val: WARNING: Ignoring corrupted image and/or label ../yolov5/data_yolov5/val/images/bing000083.jpg: invalid image format GIF
# val: New cache created: ../yolov5/data_yolov5/val/labels.cache
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        491       1424      0.896      0.876       0.93      0.754
# ...

# %%
# !cd yolov5/
# !python detect.py --weight results/weights/last.pt --img 640 --conf 0.2 --iou 0.45 --source data_yolov5/test/
# Out:
# /bin/bash: line 0: cd: yolov5/: No such file or directory
# detect: weights=['results/weights/last.pt'], source=data_yolov5/test/, imgsz=[640, 640], conf_thres=0.2, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False
# YOLOv5 🚀 v5.0-383-g8b18b66 torch 1.9.0+cpu CPU
#
# Fusing layers...
# Model Summary: 308 layers, 21057843 parameters, 0 gradients, 50.4 GFLOPs
# image 1/258 /home/thinh-do/Workspace/yolov5/data_yolov5/test/000046(1).JPG: 640x480 1 Metal, 1 Plastic, Done. (0.598s)
# image 2/258 /home/thinh-do/Workspace/yolov5/data_yolov5/test/000047(1).JPG: 640x480 1 Paper, 3 Plastics, Done. (0.417s)
# image 3/258 /home/thinh-do/Workspace/yolov5/data_yolov5/test/000047.jpg: 640x320 1 Plastic, Done. (0.424s)
# ...
